# %%
arr = [1 ,2, 3, 4, 5]
queries = [[0,3], [1,2],[ 4,1]]
for i in queries:
    id1 = i[0].value
    id2 = i[1].value

    arr[i[0]] = arr[i[1]], arr[i[1]] = arr[i[0]]
answer = arr
answer
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[6], line 4
#       2 queries = [[0,3], [1,2],[ 4,1]]
#       3 for i in queries:
# ----> 4     id1 = i[0].value
#       5     id2 = i[1].value
#       7     arr[i[0]] = arr[i[1]], arr[i[1]] = arr[i[0]]
#
# AttributeError: 'int' object has no attribute 'value'
