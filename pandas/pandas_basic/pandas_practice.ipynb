# %%
from glob import glob
import pandas as pd

filepath = 'data/*.csv'
files = glob(filepath)
print(files[8])
df = pd.read_csv(files[0],encoding='utf-8')
df.head()
# Out:
# data\소상공인시장진흥공단_상가(상권)정보_서울_202512.csv
#                  상가업소번호       상호명  지점명 상권업종대분류코드 상권업종대분류명 상권업종중분류코드 상권업종중분류명  \
# 0  MA010120220800828292     디자인바다  NaN        M1    과학·기술      M114  인쇄·제품제작
# 1  MA010120220804650800   수리봉약선요리  전문점        I2       음식      I201       한식
# 2  MA010120220804643855     북스타문고  NaN        G2       소매      G213  오락용품 소매
# 3  MA010120220804528687  봄내치킨앤떡볶이  NaN        I2       음식      I210    기타 간이
# 4  MA010120220804706623     다빈치모텔  NaN        I1       숙박      I101    일반 숙박
#
#   상권업종소분류코드      상권업종소분류명 표준산업분류코드  ...                     건물관리번호  \
# 0    M11401  명함/간판/광고물 제작   C33910  ...  4215011100112370003010826
# 1    I20101        백반/한정식   I56111  ...  4213037021102040001000001
# 2    G21301            서점   G47611  ...  4213011000111200001000001
# 3    I21007      김밥/만두/분식   I56193  ...  4211012400108130000015171
# 4    I10102         여관/모텔   I55102  ...  4215034028000500027048335
#
# ...

# %%
df2 = df.drop('상가업소번호', axis=1)
column_list = list(df2.columns)
result = []
for cname in df2.columns:
    if '코드' in cname:
        result.append(cname)

result
df2.drop(result, axis=1)
# Out:
#              상호명  지점명 상권업종대분류명     상권업종중분류명      상권업종소분류명           표준산업분류명  \
# 0          디자인바다  NaN    과학·기술      인쇄·제품제작  명함/간판/광고물 제작      간판 및 광고물 제조업
# 1        수리봉약선요리  전문점       음식           한식        백반/한정식        한식 일반 음식점업
# 2          북스타문고  NaN       소매      오락용품 소매            서점  서적; 신문 및 잡지류 소매업
# 3       봄내치킨앤떡볶이  NaN       음식        기타 간이      김밥/만두/분식            치킨 전문점
# 4          다빈치모텔  NaN       숙박        일반 숙박         여관/모텔               여관업
# ...          ...  ...      ...          ...           ...               ...
# 107448        연가  NaN       소매  섬유·의복·신발 소매     기타 의류 소매업         기타 의복 소매업
# 107449    프렌즈스크린  혁신점   예술·스포츠      스포츠 서비스        골프 연습장        골프 연습장 운영업
# 107450      애프터눈  NaN    수리·개인        이용·미용           미용실               이용업
# 107451      영아미가  NaN       음식           한식        백반/한정식        한식 일반 음식점업
# 107452      소연식당  NaN       음식           한식        백반/한정식        한식 일반 음식점업
#
# ...

# %%
result = [ cname for cname in df2.colums if '코드' in cname ]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_16584\996817722.py in ?()
# ----> 1 result = [ cname for cname in df2.colums if '코드' in cname ]
#
# c:\Users\Playdata\miniconda3\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    6317             and name not in self._accessors
#    6318             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6319         ):
#    6320             return self[name]
# -> 6321         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'colums'

# %%
df2.loc[:, '지번본번지':]

# %%
df3['상권업종소분류명'].value_counts()
