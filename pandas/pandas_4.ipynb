# %%
import pandas as pd
df = pd.read_csv('practice.csv', encoding='cp949',header=0)
df_2017 = df[df['연도'] == 2017]
df_2017.to_csv('2017.csv',encoding='utf-8')

# %%
df_2017.to_excel('2017_excel.xlsx')

# %%
df_2017.to_json('2017_json.json', force_ascii=False, orient='records', indent=2)
